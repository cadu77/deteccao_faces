# %% [markdown]
# <a href="https://colab.research.google.com/github/cadu77/deteccao_faces/blob/main/Detec%C3%A7%C3%A3o_de_faces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Carregamento da imagem**

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
imagem = cv2.imread('/content/drive/MyDrive/Visão Computacional/Images/people4.jpg')

# %%
imagem.shape
# Out:
# (344, 612, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=612x344 at 0x7FC5B48B0B10>

# %%
imagem = cv2.resize(imagem, (800, 600))
imagem.shape
# Out:
# (600, 800, 3)

# %%
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7FC5B3017C90>

# %%
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
cv2_imshow(imagem_cinza)
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7FC5B301CB50>

# %%
imagem_cinza.shape
# Out:
# (600, 800)
